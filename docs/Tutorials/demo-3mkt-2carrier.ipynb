# %% [markdown]
# # Three Market Two Carrier Test
#
# One carrier uses EMSR, the other ProBP.

# %%
import passengersim as pax

# %%
input_file = pax.demo_network("3mkt-2carrier")

# %%
input_file

# %%
sim = pax.Simulation.from_yaml(input_file)

# %%
sim.sim.snapshot_filters

# %%
summary = sim.run(log_reports=False)

# %%
summary.demands

# %%
summary.legs

# %%
summary.paths

# %%
summary.airlines

# %%
summary.airlines.set_index("name")[["asm", "rpm"]].plot.bar();

# %%
summary.fig_carrier_loads()
